# %% [markdown]
# <a href="https://colab.research.google.com/github/hamidb201214-svg/Lectures/blob/main/Workshop2_data_visualizations_solutions_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introduction to workshop 2**

# %% [markdown]
# In this Colaboratory file, we show some examples of how you can solve different types of tasks using Python. You can use these examples to guide you in solving your own tasks.
#
# ---
#
# We will use pandas to load and organize our dataset, and we will use matplotlib to visualize our data to solve the exercises for Workshop 2 (Chapters 2 and 3).

# %% [markdown]
# # Pie Chart

# %% [markdown]
# Exercise 2.13 as an example of how to create a pie chart to visualize data.

# %%
#Step 1
#Read data (example 02-13)
import pandas as pd
data = pd.read_excel('https://raw.githubusercontent.com/louisehviid/km2023/main/data/Chapter2/Xr02-13.xlsx')

# %%
data.head()
# Out:
#   Country  Oil Reserves (Barrels)
# 0  Brazil             15310000000
# 1  Canada            172500000000
# 2   China             24650000000
# 3    Iran            157800000000
# 4    Iraq            144200000000

# %%
#Step 5

# Plot the pie chart
plt.pie(percentages, labels=data['Country'], autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %%
#Step 6
#Interpret the pie chart, what can you say about the data?

# %%
# Now it's your turn, can you do the same exercise with task 2.16 (using the dataset XR02-16)?
#Import libraries we need
import pandas as pd
import matplotlib.pyplot as plt

#Read data (example 02-13)
data = pd.read_excel('https://raw.githubusercontent.com/louisehviid/km2023/main/data/Chapter2/Xr02-16.xlsx')
data.head

# no need to rename variables

# Calculate total and create a list of percentages
total = data['Proportion'].sum()
percentages = 100 * data['Proportion'] / total

# Plot the pie chart
plt.pie(percentages, labels=data['Product'], autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %%
#Import libraries we need
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Read data (example 02-15)
data = pd.read_excel('https://raw.github.com/mbaran23/statistics/main/Xr02-15.xlsx')

# %%
data.head()
# Out:
#      Country  Consumption of oil (barrels per day)
# 0  Australia                               1082000
# 1     Brazil                               3003000
# 2     Canada                               2413000
# 3      China                              10480000
# 4     France                               1706000

# %%
# Step 3
#Give the variables names that Python can work with.

# Rename the column
data.rename(columns={'Consumption of oil (barrels per day)': 'Oil_consumption'}, inplace=True)

# Verify the change
print(data)
# Out:
#            Country  Oil_consumption
# 0        Australia          1082000
# 1           Brazil          3003000
# 2           Canada          2413000
# 3            China         10480000
# 4           France          1706000
# 5          Germany          2399000
# 6            India          3660000
# 7        Indonesia          1718000
# 8             Iran          1885000
# 9            Italy          1235000
# 10           Japan          4297000
# 11          Mexico          1966000
# 12          Russia          2800000
# 13    Saudi Arabia          2961000
# 14       Singapore          1240000
# 15     South Korea          2350000
# 16           Spain          1209000
# 17        Thailand          1171000
# 18  United Kingdom          1505000
# 19   United States         19030000

# %%
# Step 4
# Calculate the percentage distribution for the pie chart.
#Making a piechart

# Calculate total and create a list of percentages
total = data['Oil_consumption'].sum()
percentages = 100 * data['Oil_consumption'] / total

# %%
total
# Out:
# 68110000

# %%
#Step 5

# Plot the pie chart
plt.pie(percentages, labels=data['Country'], autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %% [markdown]
# # Bar Chart

# %% [markdown]
# Exercise 2.13 as an example of how to create a bar chart to visualize data.

# %%
#Step 1

import pandas as pd
import matplotlib.pyplot as plt

# %%
#Step 2
# Read the data from an Excel file
data = pd.read_excel('https://raw.githubusercontent.com/louisehviid/km2023/main/data/Chapter2/Xr02-13.xlsx')

# %%
#Step 3
#Take a look at your data

data.head()
# Out:
#   Country  Oil Reserves (Barrels)
# 0  Brazil             15310000000
# 1  Canada            172500000000
# 2   China             24650000000
# 3    Iran            157800000000
# 4    Iraq            144200000000

# %%
# Step 3
# Give the variables names that Python can work with.

#Rename the column
data.rename(columns={'Oil Reserves (Barrels)': 'Oil_reserves'}, inplace=True)

# Verify the change
print(data)
# Out:
#                  Country  Oil_reserves
# 0                 Brazil   15310000000
# 1                 Canada  172500000000
# 2                  China   24650000000
# 3                   Iran  157800000000
# 4                   Iraq  144200000000
# 5             Kazakhstan   30000000000
# 6                 Kuwait  104000000000
# 7                  Libya   48360000000
# 8                Nigeria   37070000000
# 9                  Qatar   25240000000
# 10                Russia  103200000000
# 11          Saudi Arabia  268300000000
# 12  United Arab Emirates   97800000000
# 13         United States   36520000000
# 14             Venezuela  298400000000

# %%
#Step 4

#Making a bar chart

## Select the columns to use as x and y data
x = data["Country"]
y = data["Oil_reserves"]

# Plot the bar chart
plt.bar(x, y)

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

plt.xlabel('Country')
plt.ylabel('Oil Reserves')
plt.title("Bar Chart of Oil Reserves (Barrels) per Country")

plt.show()

# %%
#Step 5
# Interpret the bar graph, what does it tell us?

# %%
# Can you do the same exercise with task 2.17 (using the dataset XR02-17)?

#Import libraries we need
import pandas as pd
import matplotlib.pyplot as plt

#Read data (example 02-13)
data = pd.read_excel('https://raw.githubusercontent.com/louisehviid/km2023/main/data/Chapter2/Xr02-17.xlsx')
data.head()
# Out:
#      Country  Electricity Consumption (Kilowatt-hours)
# 0  Australia                              222600000000
# 1     Brazil                              483500000000
# 2     Canada                              524800000000
# 3      China                             5523000000000
# 4     France                              451100000000

# %%
#Rename the column
data.rename(columns={'Electricity Consumption (Kilowatt-hours)': 'Electricity'}, inplace=True)

# Verify the change
print(data)

#Making a bar chart

## Select the columns to use as x and y data
x = data["Country"]
y = data["Electricity"]

# Plot the bar chart
plt.bar(x, y)

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

plt.xlabel('Country')
plt.ylabel('Electricity')
plt.title("Bar Chart of Electricity per Country")

plt.show()
# Out:
#            Country    Electricity
# 0        Australia   222600000000
# 1           Brazil   483500000000
# 2           Canada   524800000000
# 3            China  5523000000000
# 4           France   451100000000
# 5          Germany   540100000000
# 6            India   864700000000
# 7            Italy   303100000000
# 8            Japan   921000000000
# 9     Korea, South   482400000000
# 10          Mexico   234000000000
# 11          Russia  1065000000000
# 12    Saudi Arabia   231600000000
# 13    South Africa   211600000000
# 14           Spain   243100000000
# 15          Taiwan   224300000000
# 16          Turkey   197000000000
# 17  United Kingdom   319100000000
# 18   United States  3832000000000

# %%
#Bonus task: See how to add a column to the dataset: https://youtu.be/IKiDSOUTQX8

#new column are a list of integers representing the population size
data["population_size"] = [25900000, 21430000, 38250000, 1412000000, 67750000, 83200000, 1408000000, 59110000, 125700000, 51740000, 126700000, 143400000, 35950000, 59390000, 474200000, 23570000, 847800000, 673300000, 331900000]

#generating new variable
data["Electricity_pr_population"]=data["Electricity"]/data["population_size"]

z=data["Electricity_pr_population"]

#plot
plt.bar(x, z)

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

plt.xlabel('Country')
plt.ylabel('Electricity_pr_population')
plt.title("Bar Chart of Electricity per Country")

plt.show()

# %% [markdown]
# # Histogram

# %% [markdown]
# Exercise 3.12 as an example of how to create a histogram to visualize data.

# %%
#Step 1
# import pandas to read dataset

import pandas as pd

#Read data (exercise 03-12)
data = pd.read_excel('https://raw.githubusercontent.com/louisehviid/km2023/main/data/Chapter3/Xr03-12.xlsx')

# %%
#Step 2
#Check your dataset and see which variables you have to work with.
data.head()
# Out:
#    Days
# 0     7
# 1     5
# 2     3
# 3     6
# 4     5

# %%
#Step 3
# Use your dataset to create a histogram (exercise 03-12)

#import matplotlib

import pandas as pd
import matplotlib.pyplot as plt

# Select a column to create the histogram
data = data["Days"]

# Plot the histogram
plt.hist(data, bins=20, edgecolor='black')

# Add labels and title
plt.xlabel("Days")
plt.ylabel("Frequency")
plt.title("Histogram of Days")

# Show the plot
plt.show()

# %%
#Step 4
# Interpret your histogram, what does it tell you about your data?

# %%
# Can you do the same exercise with tasks 3.13 and 3.20 (using the datasets XR03-13 and XR03-20)?

# %%
# opgave 3.13
#import pandas to read dataset

import pandas as pd

#Read data (exercise 03-13)
data = pd.read_excel('https://raw.githubusercontent.com/louisehviid/km2023/main/data/Chapter3/Xr03-13.xlsx', sheet_name= 'Xr03-15')

data.head()
# Out:
#    Customers
# 0         54
# 1         29
# 2         32
# 3         37
# 4         26

# %%
#import matplotlib

import pandas as pd
import matplotlib.pyplot as plt

# Select a column to create the histogram
data = data["Customers"]

# Plot the histogram
plt.hist(data, bins=20, edgecolor='black')

# Add labels and title
plt.xlabel("Customers")
plt.ylabel("Frequency")
plt.title("Histogram of Customers")

# Show the plot
plt.show()

# %%
# Interpret your histogram, what does it tell you about your data?

# %%
#Read data (exercise 03-20)
data = pd.read_excel('https://raw.githubusercontent.com/louisehviid/km2023/main/data/Chapter3/Xr03-20.xlsx')

# %%
# Use your dataset to create a histogram (exercise 03-20).

#import matplotlib

import pandas as pd
import matplotlib.pyplot as plt

# Select a column to create the histogram
data = data["Books"]

# Plot the histogram
plt.hist(data, bins=20, edgecolor='black')

# Add labels and title
plt.xlabel("Books")
plt.ylabel("Frequency")
plt.title("Histogram of Books")

# Show the plot
plt.show()

# %%
# Interpret your histogram, what does it tell you about your data?

# %% [markdown]
# # Line Chart

# %% [markdown]
# Exercise 3.31 as an example of how to create a line graph to visualize data.

# %%
#Step 1
# import pandas to read dataset

import pandas as pd

#Read data (exercise 03-12)
data = pd.read_excel('https://raw.githubusercontent.com/louisehviid/km2023/main/data/Chapter3/Xr03-31.xlsx')

# %%
#Step 2
#Check your dataset

data.head()
# Out:
#    Year  Health Care Total ($billions)
# 0  1950                           2.71
# 1  1951                           2.94
# 2  1952                           3.20
# 3  1953                           3.25
# 4  1954                           3.37

# %%
#Step 3
#Rename variables, so python can use them

# Rename the column
data.rename(columns={'Health Care Total ($billions)': 'Health_care'}, inplace=True)

# Verify the change
print(data)
# Out:
#     Year  Health_care
# 0   1950         2.71
# 1   1951         2.94
# 2   1952         3.20
# 3   1953         3.25
# 4   1954         3.37
# ..   ...          ...
# 61  2011      1182.94
# 62  2012      1176.83
# 63  2013      1236.95
# 64  2014      1300.26
# 65  2015      1390.68
#
# [66 rows x 2 columns]

# %%
#Step 4
#Using Matplotlib to create a line graph
import matplotlib.pyplot as plt

## Select the columns to use as x and y data
x = data["Year"]
y = data["Health_care"]

# Plot the line graph
plt.plot(x, y)

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Health Care Cost')
plt.title('Total Healthcare Cost per Year')
plt.show()

# %%
#Step 5
# What can you say about your data?

# %%
# Can you do the same exercise with task 3.32 (using the dataset XR03-32)?

import pandas as pd

#Read data (exercise 03-12)
data = pd.read_excel('https://raw.githubusercontent.com/louisehviid/km2023/main/data/Chapter3/Xr03-32.xlsx')
data.head()
# Out:
#    Year  Part A (Hospital Insurance)
# 0  1966                         0.06
# 1  1967                         2.26
# 2  1968                         3.53
# 3  1969                         3.99
# 4  1970                         4.32

# %%
#Rename variables, so python can use them

# Rename the column
data.rename(columns={'Part A (Hospital Insurance)': 'Hospital_insurance'}, inplace=True)

# Verify the change
print(data)
# Out:
#     Year  Hospital_insurance
# 0   1966                0.06
# 1   1967                2.26
# 2   1968                3.53
# 3   1969                3.99
# 4   1970                4.32
# 5   1971                4.72
# 6   1972                5.72
# 7   1973                6.41
# 8   1974                7.56
# 9   1975               10.08
# 10  1976               11.91
# 11  1977               14.25
# 12  1978               16.99
# 13  1979               19.42
# 14  1980               23.40
# 15  1981               28.39
# 16  1982               33.82
# 17  1983               33.98
# 18  1984               41.15
# 19  1985               47.28
# 20  1986               49.39
# 21  1987               49.76
# 22  1988               51.64
# 23  1989               57.13
# 24  1990               65.78
# 25  1991               69.74
# 26  1992               80.78
# 27  1993               90.49
# 28  1994              101.31
# 29  1995              113.29
# 30  1996              114.42
# 31  1997              119.11
# 32  1998              115.57
# 33  1999              106.70
# 34  2000              104.88
# 35  2001              118.54
# 36  2002              124.94
# 37  2003              131.06
# 38  2004              142.37
# 39  2005              154.88
# 40  2006              147.12
# 41  2007              157.39
# 42  2008              167.28
# 43  2009              172.37
# 44  2010              183.60
# 45  2011              190.10
# 46  2012              182.47
# 47  2013              187.58
# 48  2014              187.71
# 49  2015              193.78

# %%
#Using Matplotlib to create a line graph
import matplotlib.pyplot as plt

## Select the columns to use as x and y data
x = data["Year"]
y = data["Hospital_insurance"]

# Plot the line graph
plt.plot(x, y)

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Hospital_insurance')
plt.title('Total Hospital insurance per Year')
plt.show()

# %% [markdown]
# # Scatter plot

# %% [markdown]
# Exercise 3.54 as an example of how to create a scatter plot to visualize data.

# %%
#Step 1
# import pandas to read dataset

import pandas as pd

#Read data (exercise 03-12)
df = pd.read_excel('https://raw.githubusercontent.com/louisehviid/km2023/main/data/Chapter3/Xr03-54.xlsx')

# %%
#Step 2
#Check the dataset
df.head()
# Out:
#    Speed  Cost
# 0      3    88
# 1      6   124
# 2      9   358
# 3     12   519
# 4     15   699

# %%
#Step 3
#Using Matplotlib to create a scatterplot
import matplotlib.pyplot as plt

# Select the columns to use as x and y data
x = df["Speed"]
y = df["Cost"]

# Plot the scatter plot
plt.scatter(x, y)

# Add labels and title
plt.xlabel("Speed")
plt.ylabel("Cost")
plt.title("Cost of Speed ")

# Show the plot
plt.show()

# %%
#Step 4
# What does the graph tell you about the data?

# %%
# Can you do the same exercise with task 3.56 (using the dataset XR03-56)?

import pandas as pd

#Read data (exercise 03-56)
data = pd.read_excel('https://raw.githubusercontent.com/louisehviid/km2023/main/data/Chapter3/Xr03-56.xlsx', sheet_name= 'Xr03-61')
data.head()
# Out:
#    Time  Mark
# 0    90    68
# 1    73    65
# 2    86    58
# 3    85    94
# 4    80    76

# %%
#Using Matplotlib to create a scatterplot
import matplotlib.pyplot as plt

# Select the columns to use as x and y data
x = data["Time"]
y = data["Mark"]

# Plot the scatter plot
plt.scatter(x, y)

# Add labels and title
plt.xlabel("Time")
plt.ylabel("Mark")
plt.title("Mark of Time ")

# Show the plot
plt.show()
