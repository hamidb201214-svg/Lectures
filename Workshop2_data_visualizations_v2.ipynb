# %% [markdown]
# <a href="https://colab.research.google.com/github/hamidb201214-svg/Lectures/blob/main/Workshop2_data_visualizations_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introduction to Workshop 2: Data Visualizations**
#
# In this notebook, you will learn how to use **pandas** to load and organize datasets and **matplotlib** to visualize data using different chart types.
#
# ---

# %% [markdown]
# # 1. Pie Charts
# ### Exercise 2.13: Global Oil Reserves
# **Objective:** Create a pie chart to visualize the distribution of oil reserves by country.

# %%
# Step 1: Import libraries
import pandas as pd

# %%
# Step 2: Read data
url = 'https://raw.githubusercontent.com/louisehviid/km2023/main/data/Chapter2/Xr02-13.xlsx'
data = pd.read_excel(url)

# Step 3: Inspect data
data.head()

# %%
# Step 4: Calculate total and create a list of percentages
# Hint: Sum the 'Oil Reserves (Barrels)' column, then divide each row by that sum * 100

# %%
# Step 5: Plot the pie chart
# Use plt.pie(percentages, labels=data['Country'], autopct='%1.1f%%')

# %% [markdown]
# ### Task 2.16: Your Turn (Product Proportions)
# **Objective:** Create a pie chart for the dataset `XR02-16` following the same logic as above.

# %%
# Write your solution for Task 2.16 below
url_216 = 'https://raw.githubusercontent.com/louisehviid/km2023/main/data/Chapter2/Xr02-16.xlsx'

# %% [markdown]
# # 2. Bar Charts
# ### Exercise 2.13: Global Oil Reserves (Bar Chart)
# **Objective:** Use the same data as Exercise 1 to create a Bar Chart.

# %%
# Step 1: Rename the column 'Oil Reserves (Barrels)' to 'Oil_reserves' for easier handling

# %%
# Step 2: Plot a Bar Chart
# Hint: x-axis should be 'Country', y-axis should be 'Oil_reserves'
# Use plt.xticks(rotation=90) to prevent text overlap

# %% [markdown]
# ### Task 2.17: Electricity Consumption
# **Objective:** Create a bar chart showing oil consumption by country using dataset `XR02-17`.

# %%
# Write your solution for Task 2.17 below
url_217 = 'https://raw.githubusercontent.com/louisehviid/km2023/main/data/Chapter2/Xr02-17.xlsx'

# %% [markdown]
# # 3. Histograms
# ### Exercise 3.12: Frequency of Days
# **Objective:** Create a histogram to visualize the distribution of 'Days'.

# %%
# Step 1: Load data
url_312 = 'https://raw.githubusercontent.com/louisehviid/km2023/main/data/Chapter3/Xr03-12.xlsx'
data_days = pd.read_excel(url_312)

# Step 2: Plot Histogram
# Hint: Use plt.hist(data_days['Days'], bins=20, edgecolor='black')

# %% [markdown]
# ### Task 3.13 & 3.20: Your Turn
# **Objective:** Create histograms for `Customers` (XR03-13) and `Books` (XR03-20).
# *Note for 3.13: Use sheet_name='Xr03-15' when importing.*

# %%
# Histogram for 3.13

# %%
# Histogram for 3.20

# %% [markdown]
# # 4. Scatter Plots
# ### Exercise 3.54: Speed vs. Cost
# **Objective:** Create a scatter plot to determine if there is a relationship between Speed and Cost.

# %%
# Step 1: Load data
url_354 = 'https://raw.githubusercontent.com/louisehviid/km2023/main/data/Chapter3/Xr03-54.xlsx'
df_speed = pd.read_excel(url_354)

# Step 2: Plot Scatter
# Hint: Use plt.scatter(df_speed['Speed'], df_speed['Cost'])

# %% [markdown]
# ### Task 3.56: Time vs. Mark
# **Objective:** Use `XR03-56` (sheet_name='Xr03-61') to create a scatter plot of Time vs. Mark.

# %%
# Write your solution for Task 3.56 below
